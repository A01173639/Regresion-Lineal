# %% [markdown]
# <a href="https://colab.research.google.com/github/A01173639/Regresion-Lineal/blob/main/Act6_2_EUA_Regresi%C3%B3n_Lineal_M%C3%BAltiple_A01173639.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**ACTIVIDAD INDIVIDUAL**
# ALEXA BUSTAMANTE DE LA CRUZ
#
# A01173639

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv("EUA_clean.csv")

# %%
# Filtrar los datos para obtener solo los tipos de habitación "Entire home/apt" y "Hotel room"
private_room = df[df['room_type'] == 'Private room']
hotel_room = df[df['room_type'] == 'Hotel room']

# Unir ambos DataFrames en uno solo
df = pd.concat([private_room, hotel_room])

# %% [markdown]
# #**“host_acceptance_rate vs host_response_rate, Price, number_of_reviews , review_scores_rating”**

# %%
from turtle import color


sns.scatterplot(x='host_response_rate', y='host_acceptance_rate', color="blue", data=df)
sns.scatterplot(x='price', y='host_acceptance_rate', color="red", data=df)
sns.scatterplot(x='number_of_reviews', y='host_acceptance_rate', color="yellow", data=df)
sns.scatterplot(x='review_scores_rating', y='host_acceptance_rate', color="pink", data=df)
# Out:
# <Axes: xlabel='host_response_rate', ylabel='host_acceptance_rate'>

# %%
df['host_response_rate'] = df['host_response_rate'].str.replace('%', '.').astype(float)

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
Vars_Indep= df[['host_response_rate', 'price',  'number_of_reviews' , 'review_scores_rating']]
Var_Dep= df['host_acceptance_rate']
#Se define model como la función de regresión lineal
from sklearn.linear_model import LinearRegression
model= LinearRegression()
#Verificamos la función relacionada al modelo
type(model)
#Ajustamos el modelo con las variables antes declaradas
model.fit(X=Vars_Indep, y=Var_Dep)
#Verificamos los coeficientes obtenidos para el modelo ajustado
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['host_response_rate', 'price', 'number_of_reviews',
#         'review_scores_rating'], dtype=object),
#  'n_features_in_': 4,
#  'coef_': array([ 1.48592278e-01, -3.08723253e-04,  4.07276396e-02, -9.42362479e+00]),
#  'rank_': 4,
#  'singular_': array([9.91382580e+04, 3.23981321e+03, 9.43710483e+02, 1.23723945e+01]),
#  'intercept_': 119.30236723137524}

# %% [markdown]
# **Modelo matemático: y= 0.35979808x1 +0.00000062x2 +0.07578547x3+ (-2.72749174x4) + 66.02265**

# %%
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl=np.sqrt(coef_Deter)

print("El coeficiente de determinación es: ",coef_Deter)
print("El coeficiente de correlación es: ",coef_Correl)
# Out:
# El coeficiente de determinación es:  0.056567372003536565
# El coeficiente de correlación es:  0.23783896233278634

# %% [markdown]
# #**“Price” vs availability_365, host_response_rate, number_of_reviews, accommodates“**

# %%
from turtle import color


sns.scatterplot(x='host_response_rate', y='price', color="blue", data=df)
sns.scatterplot(x='availability_365', y='price', color="red", data=df)
sns.scatterplot(x='number_of_reviews', y='price', color="yellow", data=df)
sns.scatterplot(x='accommodates', y='price', color="pink", data=df)
# Out:
# <Axes: xlabel='host_response_rate', ylabel='price'>

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
Vars_Indep= df[['availability_365', 'host_response_rate', 'number_of_reviews', 'accommodates']]
Var_Dep= df['price']
#Se define model como la función de regresión lineal
from sklearn.linear_model import LinearRegression
model= LinearRegression()
#Verificamos la función relacionada al modelo
type(model)
#Ajustamos el modelo con las variables antes declaradas
model.fit(X=Vars_Indep, y=Var_Dep)
#Verificamos los coeficientes obtenidos para el modelo ajustado
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['availability_365', 'host_response_rate', 'number_of_reviews',
#         'accommodates'], dtype=object),
#  'n_features_in_': 4,
#  'coef_': array([ 1.61511016e-01, -8.53873463e+00, -2.24665143e+00,  2.54199535e+02]),
#  'rank_': 4,
#  'singular_': array([6647.71820735, 3243.02009534,  935.73333773,   57.41370189]),
#  'intercept_': 742.4106157256408}

# %% [markdown]
# **Modelo Matematico: y= -1.1900x1+ (-15.7766x2) + 2.8114x3 , 149.7486x4 + 2909.1855**

# %%
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl=np.sqrt(coef_Deter)

print("El coeficiente de determinación es: ",coef_Deter)
print("El coeficiente de correlación es: ",coef_Correl)
# Out:
# El coeficiente de determinación es:  0.03424698960914563
# El coeficiente de correlación es:  0.1850594218329497

# %% [markdown]
# #**“host_acceptance_rate vs number_of_reviews,review_scores_cleanliness,review_scores_communication ”**

# %%
from turtle import color

sns.scatterplot(x='number_of_reviews', y='host_acceptance_rate', color="yellow", data=df)
sns.scatterplot(x='review_scores_cleanliness', y='host_acceptance_rate', color="pink", data=df)
sns.scatterplot(x='review_scores_communication', y='host_acceptance_rate', color="red", data=df)
# Out:
# <Axes: xlabel='number_of_reviews', ylabel='host_acceptance_rate'>

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
Vars_Indep= df[['number_of_reviews','review_scores_cleanliness','review_scores_communication']]
Var_Dep= df['host_acceptance_rate']
#Se define model como la función de regresión lineal
from sklearn.linear_model import LinearRegression
model= LinearRegression()
#Verificamos la función relacionada al modelo
type(model)
#Ajustamos el modelo con las variables antes declaradas
model.fit(X=Vars_Indep, y=Var_Dep)
#Verificamos los coeficientes obtenidos para el modelo ajustado
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['number_of_reviews', 'review_scores_cleanliness',
#         'review_scores_communication'], dtype=object),
#  'n_features_in_': 3,
#  'coef_': array([ 0.04731687, -2.25197211, -9.21513039]),
#  'rank_': 3,
#  'singular_': array([3248.63561852,   13.08689562,    7.66204913]),
#  'intercept_': 143.53664100384287}

# %% [markdown]
# **Modelo matematica : y= 0.1074x1 +  2.5162x2 + (-4.7193x3)+ 96.040**

# %%
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl=np.sqrt(coef_Deter)

print("El coeficiente de determinación es: ",coef_Deter)
print("El coeficiente de correlación es: ",coef_Correl)
# Out:
# El coeficiente de determinación es:  0.033817298452381794
# El coeficiente de correlación es:  0.18389480267909095
